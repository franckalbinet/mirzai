# %%
# default_exp overview

# %%
#hide
# from mirzai import *
# from mirzai.data.core import *

# %% [markdown]
# # mirzai

# %% [markdown]
# Reproducible research code for the following paper:
#
# > Albinet et al., 2022. Prediction of Exchangeable Potassium in Soil through Mid-Infrared Spectroscopy and Deep Learning: from Prediction to Explainability. (Review name)

# %% [markdown]
# ## Install

# %% [markdown]
# `pip install mirzai`

# %% [markdown]
# ## How to use

# %% [markdown]
# ### Getting the data

# %% [markdown]
# A zipped archive of the data used in this study are available for download at the following link: [https://drive.google.com/file/d/1ozHZ8KHZeuaiv8lTycxe2-yo27BhFnUt/view?usp=sharing](https://drive.google.com/file/d/1ozHZ8KHZeuaiv8lTycxe2-yo27BhFnUt/view?usp=sharing)

# %% [markdown]
# ### In a local environment

# %% [markdown]
# The preferred way it to use [Mamba](https://mamba.readthedocs.io)

# %% [markdown]
# ### In Google Colab

# %% [markdown]
# ...

# %% [markdown]
# ## Paper reproduced

# %% [markdown]
# ...
