# %%
# default_exp paper.loading

# %% [markdown]
# # Data loading
#
# > Loading MIRS KSSL data

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mirzai.data.loading import load_data

# %%
load_data?
